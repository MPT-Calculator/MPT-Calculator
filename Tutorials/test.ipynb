# %%
# This bit of code allows a python file to be changed and then for the updates to be available without restarting
# the jupyter kernal
# %load_ext autoreload
# %autoreload 2

import numpy as np
from matplotlib import pyplot as plt
import os
# Please edit this line to provide the to the root directory of your copy of MPT-Calculator
Your_Path='/Users/cgledger/Coding/MPT-Calculator_v2_restructured/MPT-Calculator'
os.chdir(Your_Path)
os.getcwd()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '/Users/cgledger/Coding/MPT-Calculator_v2_restructured/MPT-Calculator'

# %%
from main import main;
#main(geometry='OCC_coin.py',use_OCC=True, start_stop=(1,2,1),order=0)
#main(geometry='OCC_sphere_prism_32.py',use_OCC=True, start_stop=(1,2,1),order=0)
#main(geometry='OCC_step_cube_prism.py',use_OCC=True, start_stop=(1,2,1),order=0)
dict = main(geometry='OCC_sphere_prism_32.py',use_OCC=True, use_POD=True, order=0)
# Out:
# Materials = ('mat1', 'air', 'mat1')
# Updated alpha from OCC file. Alpha=0.01
# OCC_sphere_prism_32.geo
# [0, 1] 2 ['air', 'mat1']
# Mesh Contains Prisms? True
# N Prisms: 1275, N Tets: 21197
# [0, 1] 2 ['air', 'mat1']
# /Users/cgledger/Coding/MPT-Calculator_v2_restructured/MPT-Calculator/main.py:255: UserWarning: It looks like the main function was invoked from a jupyter notebook.
# Currently saving a .ipynb file is done by copying the most recent file in the .ipynb_checkpoints folder.
# Unless you saved the file before running the code, this may not be the correct file.
#   warn('It looks like the main function was invoked from a jupyter notebook. \nCurrently saving a .ipynb file is done by copying the most recent file in the .ipynb_checkpoints folder. \nUnless you saved the file before running the code, this may not be the correct file.', stacklevel=1)
#  problems solved
#  matrices computed
#  eigenvalue problem solved
# Predicted conductor volume is 4.18878948971651e-06
# ...

# %%
def myinout(index,n,ntags):
    prod=1.
    den=1.
    for k in range(0,ntags+1):
        if k != n:
            prod = prod*(index-k)
            den = den*(n-k)
    return prod/den

# %%
myinout(0,3,3)
# Out:
# 1.0
