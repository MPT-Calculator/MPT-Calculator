# %%
from time import time
import numpy as np
from matplotlib import pyplot as plt
import os
root_dir = os.path.dirname(os.getcwd())
os.chdir(root_dir)

# %% [markdown]
# # POD Frequency Sweep
#
# In this example, we explore the use of Proper Orthogonal Decomposition (POD) for accelerating the computation of the MPT over a range of exciting frequencies.

# %%
from runner import main
# Out:
# importing NGSolve-6.2.2202

# %%
start_time = time();
main(use_POD=True);
stop_time = time();
# Out:
# sphere.geo
#  mesh contains 9814 elements
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
#  solved theta0 problems
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# manually closed pool
#  SVD complete
# importing NGSolve-6.2.2202del
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# importing NGSolve-6.2.2202
# manually closed pooler system 39/40
#  reduced order systems solved
#  frequency sweep complete

# %%
print(f'Total time = {stop_time - start_time}')
# Out:
# Total time = 45.709736585617065

# %% [markdown]
# ## Estimating ROM Error:
#
# We can estimate upper limits on the accuracy of the POD method within the software.
# We do this within $\texttt{Settings.py}$ by changing
# ```python
# #Produce certificate bounds for POD outputs
#     PODErrorBars = False
#     #(boolean)
# ```
# to True
